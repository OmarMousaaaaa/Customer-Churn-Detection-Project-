# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarMousaaaaa/Customer-Churn-Detection-Project-/blob/main/NLP%20Task%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag, ne_chunk

# Necessary NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('words')

# Text
text_data = [
    "The movie was fantastic and I loved every part of it about Egypt",
    "I hated the film, it was the worst I have ever seen",
    "The storyline was boring but the acting was brilliant",
    "An amazing movie with a great plot and incredible performances",
    "Egypt movie, I regret wasting my time on it",
    "The actors did a great job but the story lacked depth",
    "One of the best films I have seen in a long time, highly recommend it",
    "This film was just okay, not too bad but not great either",
    "Absolutely loved the movie, fantastic plot and wonderful cast",
    "The movie was disappointing, it did not live up to the hype"
]

# Enabling NLP tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()


# Processes
for i in text_data:
    print("\nOriginal Sentence:", i)

    # Tokenization
    tokens = word_tokenize(i)
    print("Tokens:", tokens)

    # Stopword Removal
    filtered_tokens = []
    for word in tokens:
      if word.lower() not in stop_words:
        filtered_tokens.append(word)
    print("Filtered Tokens (without stopwords):", filtered_tokens)

    # Stemming and Lemmatization
    stemmed_words = []
    for word in filtered_tokens:
     stemmed_words.append(stemmer.stem(word))
    print("Stemmed Words:", stemmed_words)
    lemmatized_words = []
    for word in filtered_tokens:
      lemmatized_words.append(lemmatizer.lemmatize(word))
    print("Lemmatized Words:", lemmatized_words)

    # POS Tagging
    pos_tags = pos_tag(filtered_tokens)
    print("POS Tags:", pos_tags)

    # NER
    named_entities = ne_chunk(pos_tags)
    print("Named Entities:", named_entities)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Original Sentence: The movie was fantastic and I loved every part of it about Egypt
# Tokens: ['The', 'movie', 'was', 'fantastic', 'and', 'I', 'loved', 'every', 'part', 'of', 'it', 'about', 'Egypt']
# Filtered Tokens (without stopwords): ['movie', 'fantastic', 'loved', 'every', 'part', 'Egypt']
# Stemmed Words: ['movi', 'fantast', 'love', 'everi', 'part', 'egypt']
# Lemmatized Words: ['movie', 'fantastic', 'loved', 'every', 'part', 'Egypt']
# POS Tags: [('movie', 'NN'), ('fantastic', 'JJ'), ('loved', 'VBN'), ('every', 'DT'), ('part', 'NN'), ('Egypt', 'NNP')]
# Named Entities: (S
#   movie/NN
#   fantastic/JJ
#   loved/VBN
#   every/DT
#   part/NN
#   (PERSON Egypt/NNP))
#
# Original Sentence: I hated the film, it was the worst I have ever seen
# Tokens: ['I', 'hated', 'the', 'film', ',', 'it', 'was', 'the', 'worst', 'I', 'have', 'ever', 'seen']
# Filtered Tokens (without stopwords): ['hated', 'film', ',', 'worst', 'ever', 'seen']
# Stemmed Words: ['hate', 'film', ',', 'worst', 'ever', 'seen']
# Lemmatized Words: ['hated', 'film', ',', 'worst', 'ever', 'seen']
# POS Tags: [('hated', 'VBN'), ('film', 'NN'), (',', ','), ('worst', 'WP'), ('ever', 'RB'), ('seen', 'VBN')]
# Named Entities: (S hated/VBN film/NN ,/, worst/WP ever/RB seen/VBN)
#
# Original Sentence: The storyline was boring but the acting was brilliant
# Tokens: ['The', 'storyline', 'was', 'boring', 'but', 'the', 'acting', 'was', 'brilliant']
# Filtered Tokens (without stopwords): ['storyline', 'boring', 'acting', 'brilliant']
# Stemmed Words: ['storylin', 'bore', 'act', 'brilliant']
# Lemmatized Words: ['storyline', 'boring', 'acting', 'brilliant']
# POS Tags: [('storyline', 'NN'), ('boring', 'VBG'), ('acting', 'VBG'), ('brilliant', 'NN')]
# Named Entities: (S storyline/NN boring/VBG acting/VBG brilliant/NN)
#
# Original Sentence: An amazing movie with a great plot and incredible performances
# Tokens: ['An', 'amazing', 'movie', 'with', 'a', 'great', 'plot', 'and', 'incredible', 'performances']
# Filtered Tokens (without stopwords): ['amazing', 'movie', 'great', 'plot', 'incredible', 'performances']
# Stemmed Words: ['amaz', 'movi', 'great', 'plot', 'incred', 'perform']
# Lemmatized Words: ['amazing', 'movie', 'great', 'plot', 'incredible', 'performance']
# POS Tags: [('amazing', 'JJ'), ('movie', 'NN'), ('great', 'JJ'), ('plot', 'NN'), ('incredible', 'JJ'), ('performances', 'NNS')]
# Named Entities: (S
#   amazing/JJ
#   movie/NN
#   great/JJ
#   plot/NN
#   incredible/JJ
#   performances/NNS)
#
# Original Sentence: Egypt movie, I regret wasting my time on it
# Tokens: ['Egypt', 'movie', ',', 'I', 'regret', 'wasting', 'my', 'time', 'on', 'it']
# Filtered Tokens (without stopwords): ['Egypt', 'movie', ',', 'regret', 'wasting', 'time']
# Stemmed Words: ['egypt', 'movi', ',', 'regret', 'wast', 'time']
# Lemmatized Words: ['Egypt', 'movie', ',', 'regret', 'wasting', 'time']
# POS Tags: [('Egypt', 'NNP'), ('movie', 'NN'), (',', ','), ('regret', 'VB'), ('wasting', 'NN'), ('time', 'NN')]
# Named Entities: (S (GPE Egypt/NNP) movie/NN ,/, regret/VB wasting/NN time/NN)
#
# Original Sentence: The actors did a great job but the story lacked depth
# Tokens: ['The', 'actors', 'did', 'a', 'great', 'job', 'but', 'the', 'story', 'lacked', 'depth']
# Filtered Tokens (without stopwords): ['actors', 'great', 'job', 'story', 'lacked', 'depth']
# Stemmed Words: ['actor', 'great', 'job', 'stori', 'lack', 'depth']
# Lemmatized Words: ['actor', 'great', 'job', 'story', 'lacked', 'depth']
# POS Tags: [('actors', 'NNS'), ('great', 'JJ'), ('job', 'NN'), ('story', 'NN'), ('lacked', 'VBD'), ('depth', 'NN')]
# Named Entities: (S actors/NNS great/JJ job/NN story/NN lacked/VBD depth/NN)
#
# Original Sentence: One of the best films I have seen in a long time, highly recommend it
# Tokens: ['One', 'of', 'the', 'best', 'films', 'I', 'have', 'seen', 'in', 'a', 'long', 'time', ',', 'highly', 'recommend', 'it']
# Filtered Tokens (without stopwords): ['One', 'best', 'films', 'seen', 'long', 'time', ',', 'highly', 'recommend']
# Stemmed Words: ['one', 'best', 'film', 'seen', 'long', 'time', ',', 'highli', 'recommend']
# Lemmatized Words: ['One', 'best', 'film', 'seen', 'long', 'time', ',', 'highly', 'recommend']
# POS Tags: [('One', 'CD'), ('best', 'JJS'), ('films', 'NNS'), ('seen', 'VBN'), ('long', 'JJ'), ('time', 'NN'), (',', ','), ('highly', 'RB'), ('recommend', 'VB')]
# Named Entities: (S
#   One/CD
#   best/JJS
#   films/NNS
#   seen/VBN
#   long/JJ
#   time/NN
#   ,/,
#   highly/RB
#   recommend/VB)
#
# Original Sentence: This film was just okay, not too bad but not great either
# Tokens: ['This', 'film', 'was', 'just', 'okay', ',', 'not', 'too', 'bad', 'but', 'not', 'great', 'either']
# Filtered Tokens (without stopwords): ['film', 'okay', ',', 'bad', 'great', 'either']
# Stemmed Words: ['film', 'okay', ',', 'bad', 'great', 'either']
# Lemmatized Words: ['film', 'okay', ',', 'bad', 'great', 'either']
# POS Tags: [('film', 'NN'), ('okay', 'NN'), (',', ','), ('bad', 'JJ'), ('great', 'JJ'), ('either', 'CC')]
# Named Entities: (S film/NN okay/NN ,/, bad/JJ great/JJ either/CC)
#
# Original Sentence: Absolutely loved the movie, fantastic plot and wonderful cast
# Tokens: ['Absolutely', 'loved', 'the', 'movie', ',', 'fantastic', 'plot', 'and', 'wonderful', 'cast']
# Filtered Tokens (without stopwords): ['Absolutely', 'loved', 'movie', ',', 'fantastic', 'plot', 'wonderful', 'cast']
# Stemmed Words: ['absolut', 'love', 'movi', ',', 'fantast', 'plot', 'wonder', 'cast']
# Lemmatized Words: ['Absolutely', 'loved', 'movie', ',', 'fantastic', 'plot', 'wonderful', 'cast']
# POS Tags: [('Absolutely', 'RB'), ('loved', 'JJ'), ('movie', 'NN'), (',', ','), ('fantastic', 'JJ'), ('plot', 'NN'), ('wonderful', 'JJ'), ('cast', 'NN')]
# Named Entities: (S
#   Absolutely/RB
#   loved/JJ
#   movie/NN
#   ,/,
#   fantastic/JJ
#   plot/NN
#   wonderful/JJ
#   cast/NN)
#
# Original Sentence: The movie was disappointing, it did not live up to the hype
# Tokens: ['The', 'movie', 'was', 'disappointing', ',', 'it', 'did', 'not', 'live', 'up', 'to', 'the', 'hype']
# Filtered Tokens (without stopwords): ['movie', 'disappointing', ',', 'live', 'hype']
# Stemmed Words: ['movi', 'disappoint', ',', 'live', 'hype']
# Lemmatized Words: ['movie', 'disappointing', ',', 'live', 'hype']
# POS Tags: [('movie', 'NN'), ('disappointing', 'NN'), (',', ','), ('live', 'VBP'), ('hype', 'NN')]
# Named Entities: (S movie/NN disappointing/NN ,/, live/VBP hype/NN)
